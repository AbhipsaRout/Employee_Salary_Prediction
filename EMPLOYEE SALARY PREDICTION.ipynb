# %%
import pandas as pd    #for data  manipulation and analysis

# %%
data=pd.read_csv(r"C:\Users\KIIT0001\Desktop\New folder\adult 3 (2).csv")

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.head(1)
# Out:
#    age workclass  fnlwgt education  educational-num marital-status  \
# 0   25   Private  226802      11th                7  Never-married
#
#           occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K

# %% [markdown]
# ### Data cleaning

# %%
data.info
# Out:
# <bound method DataFrame.info of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
# to find null value
data.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.tail(3)
# Out:
#        age     workclass  fnlwgt education  educational-num  \
# 48839   58       Private  151910   HS-grad                9
# 48840   22       Private  201490   HS-grad                9
# 48841   52  Self-emp-inc  287927   HS-grad                9
#
#            marital-status       occupation relationship   race  gender  \
# 48839             Widowed     Adm-clerical    Unmarried  White  Female
# 48840       Never-married     Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse  Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K

# %%
data.shape
# Out:
# (48842, 15)

# %%
print(data.age.value_counts())
# Out:
# age
# 36    1348
# 35    1337
# 33    1335
# 23    1329
# 31    1325
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
print(data.education.value_counts())
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
print(data['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(data.relationship.value_counts())
# Out:
# relationship
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64

# %%
print(data.race.value_counts())
# Out:
# race
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
print(data.gender.value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
print(data['capital-gain'].value_counts())
# Out:
# capital-gain
# 0        44807
# 15024      513
# 7688       410
# 7298       364
# 99999      244
#          ...
# 1111         1
# 7262         1
# 22040        1
# 1639         1
# 2387         1
# Name: count, Length: 123, dtype: int64

# %%
print(data['capital-loss'].value_counts())
# Out:
# capital-loss
# 0       46560
# 1902      304
# 1977      253
# 1887      233
# 2415       72
#         ...
# 2465        1
# 2080        1
# 155         1
# 1911        1
# 2201        1
# Name: count, Length: 99, dtype: int64

# %%
print(data['hours-per-week'].value_counts())
# Out:
# hours-per-week
# 40    22803
# 50     4246
# 45     2717
# 60     2177
# 35     1937
#       ...
# 69        1
# 87        1
# 94        1
# 82        1
# 79        1
# Name: count, Length: 96, dtype: int64

# %%
print(data['native-country'].value_counts())
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
print(data.income.value_counts())
# Out:
# income
# <=50K    37155
# >50K     11687
# Name: count, dtype: int64

# %%
# replacethe special characters with some name
data.occupation.replace({'?':'others'},inplace=True)

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
data['native-country'].replace({'?':'others'},inplace=True)
data['workclass'].replace({'?':'others'},inplace=True)

# %%
print(data['native-country'].value_counts())
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# others                          857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18        others  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %% [markdown]
# ### Remove meaningless data / unwanted data

# %%
data = data[data['workclass']!='Never-worked']

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Name: count, dtype: int64

# %%
data = data[data['workclass']!='Without-pay']

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
data = data[data['native-country']!='Holand-Netherlands']
print(data['native-country'].value_counts())
# Out:
# native-country
# United-States                 43802
# Mexico                          951
# others                          857
# Philippines                     294
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
data = data[data['occupation']!='Armed-Forces']
print(data['occupation'].value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6111
# Exec-managerial      6085
# Adm-clerical         5608
# Sales                5503
# Other-service        4921
# Machine-op-inspct    3019
# others               2799
# Transport-moving     2354
# Handlers-cleaners    2070
# Farming-fishing      1482
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Name: count, dtype: int64

# %%
data = data[data['marital-status']!='Married-AF-spouse']
print(data['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22358
# Never-married            16095
# Divorced                  6632
# Separated                 1530
# Widowed                   1517
# Married-spouse-absent      626
# Name: count, dtype: int64

# %%
data = data[data['education']!='Preschool']
print(data['education'].value_counts())
# Out:
# education
# HS-grad         15748
# Some-college    10859
# Bachelors        8018
# Masters          2655
# Assoc-voc        2058
# 11th             1809
# Assoc-acdm       1597
# 10th             1386
# 7th-8th           952
# Prof-school       832
# 9th               756
# 12th              656
# Doctorate         593
# 5th-6th           509
# 1st-4th           247
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (48675, 15)

# %% [markdown]
# ### redundancy

# %%
#drop education column
data.drop(columns=['education'],inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18        others  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data['age'])
plt.show()

# %%
# remove the out layers

# %%
# this boxplot shows the age starts from 20 and age 80 to 90 are outlayers as they are retired person or unemployeed or something else but their has not remover yet
print(data['age'].value_counts())
# Out:
# age
# 36    1346
# 35    1334
# 33    1333
# 23    1322
# 31    1320
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
data = data[(data['age']<=75)& (data['age']>=17)]

# %%
# the outlier has been removed
plt.boxplot(data['age'])
plt.show()

# %%
plt.boxplot(data['educational-num'])
plt.show()

# %%
data=data[(data['educational-num']<=16) & (data['educational-num']>5)]
plt.boxplot(data['educational-num'])
plt.show()

# %%
plt.boxplot(data['capital-gain'])
plt.show()

# %%
plt.boxplot(data['capital-loss'])
plt.show()

# %%
plt.boxplot(data['hours-per-week'])
plt.show()

# %%
data=data[(data['hours-per-week']>=39.5) & (data['hours-per-week']<=45)]
plt.boxplot(data['hours-per-week'])
plt.show()

# %%
data=data[(data['capital-gain']>=0) & (data['capital-gain']<=100)]
plt.boxplot(data['capital-gain'])
plt.show()

# %%
data=data[(data['capital-loss']>=0) & (data['capital-loss']<=100)]
plt.boxplot(data['capital-loss'])
plt.show()

# %% [markdown]
# ### Levelencoding

# %%
# to convert the categorical value into numerical value
# Gender
# Female -> 0
# Male -> 1
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
# fit.transform is a method used to convert
data['workclass']=encoder.fit_transform(data['workclass'])
data['marital-status']=encoder.fit_transform(data['marital-status'])
data['occupation']=encoder.fit_transform(data['occupation'])
data['relationship']=encoder.fit_transform(data['relationship'])
data['race']=encoder.fit_transform(data['race'])
data['gender']=encoder.fit_transform(data['gender'])
data['native-country']=encoder.fit_transform(data['native-country'])

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          2  226802                7               3           5
# 2       28          1  336951               12               1           9
# 6       29          6  227026                9               3          13
# 8       24          2  369667               10               3           6
# 11      36          0  212465               13               1           0
# ...    ...        ...     ...              ...             ...         ...
# 48833   43          2   84661               11               1          10
# 48835   53          2  321865               14               1           2
# 48836   22          2  310152               10               3           9
# 48838   40          2  154374                9               1           5
# 48839   58          2  151910                9               5           0
#
# ...

# %%
plt.pie(data['gender'].value_counts(), labels=['Male','Female'],autopct="%0.2f")
plt.show()

# %%
plt.pie(data['income'].value_counts(), labels=['>50k','<=50k'],autopct="%0.2f")
plt.show()

# %%
plt.boxplot(data['marital-status'])
plt.show()

# %%
plt.boxplot(data['workclass'])
plt.show()

# %%
data=data[(data['workclass']>1) & (data['workclass']<3)]
plt.boxplot(data['workclass'])
plt.show()

# %%
# devide the data into two parts 
# Tranining & Tasting Data
x= data.drop(columns=['income']) # input
y= data['income'] # output

# %%
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          2  226802                7               3           5
# 8       24          2  369667               10               3           6
# 19      40          2   85019               16               1           8
# 23      25          2  220931               13               3           8
# 24      25          2  205947               13               1           8
# ...    ...        ...     ...              ...             ...         ...
# 48833   43          2   84661               11               1          10
# 48835   53          2  321865               14               1           2
# 48836   22          2  310152               10               3           9
# 48838   40          2  154374                9               1           5
# 48839   58          2  151910                9               5           0
#
# ...

# %%
y
# Out:
# 0        <=50K
# 8        <=50K
# 19        >50K
# 23       <=50K
# 24       <=50K
#          ...
# 48833    <=50K
# 48835     >50K
# 48836    <=50K
# 48838     >50K
# 48839    <=50K
# Name: income, Length: 16098, dtype: object

# %%
# scaling
# the value range will be from 0 to 1
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()
x=Scaler.fit_transform(x)

# %%
x
# Out:
# array([[0.13793103, 0.        , 0.14426962, ..., 0.        , 0.        ,
#         0.925     ],
#        [0.12068966, 0.        , 0.24102027, ..., 0.        , 0.        ,
#         0.925     ],
#        [0.39655172, 0.        , 0.04825173, ..., 0.        , 1.        ,
#         1.        ],
#        ...,
#        [0.0862069 , 0.        , 0.20071568, ..., 0.        , 0.        ,
#         0.925     ],
#        [0.39655172, 0.        , 0.09522013, ..., 0.        , 0.        ,
#         0.925     ],
#        [0.70689655, 0.        , 0.09355147, ..., 0.        , 0.        ,
#         0.925     ]])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest =train_test_split(x,y,test_size=0.2,random_state=23,stratify=y)
# stratify :- the data or the value should be equally distributed
# random_state: - the data will remain in the same ratio i.e 20:80 or same data point

# %%
xtrain
# Out:
# array([[0.5       , 0.        , 0.03604963, ..., 0.        , 0.        ,
#         0.925     ],
#        [0.06896552, 0.        , 0.29721102, ..., 0.        , 0.        ,
#         0.925     ],
#        [0.48275862, 0.        , 0.1549358 , ..., 0.        , 0.        ,
#         0.925     ],
#        ...,
#        [0.34482759, 0.        , 0.1747207 , ..., 0.        , 1.        ,
#         0.925     ],
#        [0.63793103, 0.        , 0.07398057, ..., 0.        , 0.        ,
#         0.725     ],
#        [0.25862069, 0.        , 0.26087696, ..., 0.        , 0.        ,
#         0.925     ]])

# %%
# through train test no of times the machine will try to learn the data from the  perticular pattern

# %%
# !pip  install xgboost
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "GradientBoosting": GradientBoostingClassifier(),
    "adb": AdaBoostClassifier(),
    "bc": BaggingClassifier(),
    "NaiveBayes": GaussianNB(),
    "ExtraTrees": ExtraTreesClassifier(),
    "DecisionTree": DecisionTreeClassifier(),
}

results = {}

for name, model in models.items():
    
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])
    
    pipe.fit(xtrain, ytrain)
    y_pred = pipe.predict(xtest)
    acc = accuracy_score(ytest, y_pred)
    results[name] = acc
    
    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(ytest, y_pred))
# Out:
# LogisticRegression Accuracy: 0.8382
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.96      0.91      2659
#         >50K       0.59      0.24      0.34       561
#
#     accuracy                           0.84      3220
#    macro avg       0.72      0.60      0.63      3220
# weighted avg       0.81      0.84      0.81      3220
#
# RandomForest Accuracy: 0.8444
#               precision    recall  f1-score   support
#
#        <=50K       0.89      0.93      0.91      2659
#         >50K       0.57      0.45      0.50       561
#
#     accuracy                           0.84      3220
#    macro avg       0.73      0.69      0.71      3220
# weighted avg       0.83      0.84      0.84      3220
#
# KNN Accuracy: 0.8326
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.92      0.90      2659
#         >50K       0.52      0.43      0.47       561
#
# ...

# %%
data = pd.DataFrame({'Algorithm':results.keys(),'Accuracy':results.values()}).sort_values('Accuracy',ascending=False)

# %%
data
# Out:
#             Algorithm  Accuracy
# 4    GradientBoosting  0.860248
# 5                 adb  0.853106
# 3                 SVM  0.847826
# 1        RandomForest  0.844410
# 8          ExtraTrees  0.840062
# 0  LogisticRegression  0.838199
# 2                 KNN  0.832609
# 6                  bc  0.829503
# 9        DecisionTree  0.799379
# 7          NaiveBayes  0.793478

# %%
from sklearn.ensemble import VotingClassifier
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

voting = VotingClassifier(estimators=[("adb", AdaBoostClassifier(),
),( "GradientBoosting", GradientBoostingClassifier()),("RandomForest", RandomForestClassifier())
],voting='soft')

# %%
#voting.fit(xtrain,ytrain)

voting_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('model', voting)
])
voting_pipe.fit(xtrain, ytrain)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model',
#                  VotingClassifier(estimators=[('adb', AdaBoostClassifier()),
#                                               ('GradientBoosting',
#                                                GradientBoostingClassifier()),
#                                               ('RandomForest',
#                                                RandomForestClassifier())],
#                                   voting='soft'))])

# %%
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "GradientBoosting": GradientBoostingClassifier(),
    "adb": AdaBoostClassifier(),
    "bc": BaggingClassifier(),
    "NaiveBayes": GaussianNB(),
    "ExtraTrees": ExtraTreesClassifier(),
    "DecisionTree": DecisionTreeClassifier(),
    "VotingClassifier": voting
}

results = {}

for name, model in models.items():
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])
    
    pipe.fit(xtrain, ytrain)
    y_pred = pipe.predict(xtest)
    acc = accuracy_score(ytest, y_pred)
    results[name] = acc

    print(f"{name} Accuracy: {acc:.4f}")
    print(classification_report(ytest, y_pred))
# Out:
# LogisticRegression Accuracy: 0.8382
#               precision    recall  f1-score   support
#
#        <=50K       0.86      0.96      0.91      2659
#         >50K       0.59      0.24      0.34       561
#
#     accuracy                           0.84      3220
#    macro avg       0.72      0.60      0.63      3220
# weighted avg       0.81      0.84      0.81      3220
#
# RandomForest Accuracy: 0.8401
#               precision    recall  f1-score   support
#
#        <=50K       0.89      0.92      0.91      2659
#         >50K       0.55      0.45      0.49       561
#
#     accuracy                           0.84      3220
#    macro avg       0.72      0.68      0.70      3220
# weighted avg       0.83      0.84      0.83      3220
#
# KNN Accuracy: 0.8326
#               precision    recall  f1-score   support
#
#        <=50K       0.88      0.92      0.90      2659
#         >50K       0.52      0.43      0.47       561
#
# ...

# %%
data = pd.DataFrame({'Algorithm':results.keys(),'Accuracy':results.values()}).sort_values('Accuracy',ascending=False)

# %%
data
# Out:
#              Algorithm  Accuracy
# 4     GradientBoosting  0.860248
# 10    VotingClassifier  0.854348
# 5                  adb  0.853106
# 3                  SVM  0.847826
# 1         RandomForest  0.840062
# 0   LogisticRegression  0.838199
# 8           ExtraTrees  0.836025
# 6                   bc  0.833540
# 2                  KNN  0.832609
# 9         DecisionTree  0.795031
# 7           NaiveBayes  0.793478

# %%
import matplotlib.pyplot as plt

# Create a list of colors (as many as the number of algorithms)
#colors = ['skyblue', 'lightgreen', 'salmon', 'orange', 'violet', 'gold', 'lightcoral', 'turquoise']

# Adjust the number of colors to match the number of bars
#colors = colors[:len(data)]

# Plot bar chart from DataFrame
plt.figure(figsize=(12, 6))
plt.bar(data['Algorithm'], data['Accuracy'], color='turquoise')
plt.ylabel('Accuracy Score')
plt.title('Model Comparison')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
##from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
#from sklearn.model_selection import cross_val_score

# Confusion Matrix for GradientBoosting
#cm = confusion_matrix(ytest, y_pred)
##disp = ConfusionMatrixDisplay(confusion_matrix=cm)
##disp.plot(cmap='Blues')
#plt.title("Confusion Matrix - GradientBoosting ")
#plt.show()


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Ensure GradientBoosting model is defined and trained
gb_model = GradientBoostingClassifier()
gb_model.fit(xtrain, ytrain)

# Make predictions
y_pred_gb = gb_model.predict(xtest)

# Generate confusion matrix
cm = confusion_matrix(ytest, y_pred_gb)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix - GradientBoosting")
plt.show()

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import joblib  # for saving the model

# Split data
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# Define models
models = {
    "LogisticRegression": LogisticRegression(),
    "RandomForest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "GradientBoosting": GradientBoostingClassifier(),
    "adb": AdaBoostClassifier(),
    "bc": BaggingClassifier(),
    "NaiveBayes": GaussianNB(),
    "ExtraTrees": ExtraTreesClassifier(),
    "DecisionTree": DecisionTreeClassifier(),
    "VotingClassifier": voting

}

# Store results
results = {}

for name, model in models.items():
    model.fit(xtrain, ytrain)
    preds = model.predict(xtest)
    acc = accuracy_score(ytest, preds)
    results[name] = acc
    print(f"{name}: {acc:.4f}")

# Get best model
best_model_name = max(results, key=results.get)
best_model = models[best_model_name]
print(f"\nBest model: {best_model_name} with accuracy: {results[best_model_name]:.4f}")

# Save the best model
joblib.dump(best_model, f"{best_model_name}_model.pkl")
print(f"Model saved as {best_model_name}_model.pkl")
# Out:
# LogisticRegression: 0.8379
# RandomForest: 0.8401
# KNN: 0.8354
# SVM: 0.8453
# GradientBoosting: 0.8602
# adb: 0.8531
# bc: 0.8329
# NaiveBayes: 0.7935
# ExtraTrees: 0.8370
# DecisionTree: 0.7947
# VotingClassifier: 0.8571
#
# Best model: GradientBoosting with accuracy: 0.8602
# Model saved as GradientBoosting_model.pkl
